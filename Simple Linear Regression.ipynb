# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as  plt
# %matplotlib inline

# %%
df=pd.read_csv('D:\Lockdown days\Coursera\Machine learning with python\FuelConsumption.csv')

# %%
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
df.drop(df.columns[0:4],axis=1).head() #dropping columns by index
# Out:
#    ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  \
# 0         2.0          4          AS5        Z                   9.9
# 1         2.4          4           M6        Z                  11.2
# 2         1.5          4          AV7        Z                   6.0
# 3         3.5          6          AS6        Z                  12.7
# 4         3.5          6          AS6        Z                  12.1
#
#    FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# 0                  6.7                   8.5                        33
# 1                  7.7                   9.6                        29
# 2                  5.8                   5.9                        48
# 3                  9.1                  11.1                        25
# 4                  8.7                  10.6                        27
#
#    CO2EMISSIONS
# 0           196
# 1           221
# 2           136
# 3           255
# 4           244

# %%
df.drop([0,1,2,3],axis=0).head() #dropping rows by index
# Out:
#    MODELYEAR   MAKE    MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION  \
# 4       2014  ACURA  RDX AWD  SUV - SMALL         3.5          6          AS6
# 5       2014  ACURA      RLX     MID-SIZE         3.5          6          AS6
# 6       2014  ACURA       TL     MID-SIZE         3.5          6          AS6
# 7       2014  ACURA   TL AWD     MID-SIZE         3.7          6          AS6
# 8       2014  ACURA   TL AWD     MID-SIZE         3.7          6           M6
#
#   FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 4        Z                  12.1                  8.7                  10.6
# 5        Z                  11.9                  7.7                  10.0
# 6        Z                  11.8                  8.1                  10.1
# 7        Z                  12.8                  9.0                  11.1
# 8        Z                  13.4                  9.5                  11.6
#
# ...

# %%
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
cdf=df.drop(df.columns[1:4],axis=1)

# %%
cdf.head()
# Out:
#    MODELYEAR  ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  \
# 0       2014         2.0          4          AS5        Z
# 1       2014         2.4          4           M6        Z
# 2       2014         1.5          4          AV7        Z
# 3       2014         3.5          6          AS6        Z
# 4       2014         3.5          6          AS6        Z
#
#    FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# 0                   9.9                  6.7                   8.5
# 1                  11.2                  7.7                   9.6
# 2                   6.0                  5.8                   5.9
# 3                  12.7                  9.1                  11.1
# 4                  12.1                  8.7                  10.6
#
#    FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                        33           196
# 1                        29           221
# 2                        48           136
# ...

# %%
df.columns
# Out:
# Index(['MODELYEAR', 'MAKE', 'MODEL', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUELTYPE', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='object')

# %%
cdf.columns
# Out:
# Index(['MODELYEAR', 'ENGINESIZE', 'CYLINDERS', 'TRANSMISSION', 'FUELTYPE',
#        'FUELCONSUMPTION_CITY', 'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='object')

# %%
cdf.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# ...

# %%
fd = cdf[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB','CO2EMISSIONS']]
fd.head(9)
# Out:
#    ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0         2.0          4                   8.5           196
# 1         2.4          4                   9.6           221
# 2         1.5          4                   5.9           136
# 3         3.5          6                  11.1           255
# 4         3.5          6                  10.6           244
# 5         3.5          6                  10.0           230
# 6         3.5          6                  10.1           232
# 7         3.7          6                  11.1           255
# 8         3.7          6                  11.6           267

# %%
fd.hist()
plt.show()

# %%
plt.scatter(fd.FUELCONSUMPTION_COMB, fd.CO2EMISSIONS,  color='blue')
plt.xlabel("FUELCONSUMPTION_COMB")
plt.ylabel("Emission")
plt.show()

# %%
plt.scatter(fd.ENGINESIZE, fd.CO2EMISSIONS,  color='red',marker='+')
plt.xlabel("Engine size")
plt.ylabel("Emission")
plt.show()

# %%
plt.scatter(cdf.CYLINDERS, cdf.CO2EMISSIONS, color='green',marker='*')
plt.xlabel("Cylinders")
plt.ylabel("Emission")
plt.show()

# %% [markdown]
# Creating train and test dataset

# %%
msk = np.random.rand(len(df)) < 0.8
train = fd[msk]
test = fd[~msk]

# %%
train.head()
# Out:
#    ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0         2.0          4                   8.5           196
# 1         2.4          4                   9.6           221
# 2         1.5          4                   5.9           136
# 3         3.5          6                  11.1           255
# 4         3.5          6                  10.6           244

# %%
test.head()
# Out:
#     ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 6          3.5          6                  10.1           232
# 8          3.7          6                  11.6           267
# 9          2.4          4                   9.2           212
# 18         5.9         12                  15.6           359
# 25         2.0          4                  10.2           235

# %%
from sklearn.linear_model import LinearRegression

# %%
plt.scatter(train.ENGINESIZE, train.CO2EMISSIONS,  color='blue')
plt.xlabel("Engine size")
plt.ylabel("Emission")
plt.show()

# %%
plt.scatter(test.ENGINESIZE, test.CO2EMISSIONS,  color='blue')
plt.xlabel("Engine size")
plt.ylabel("Emission")
plt.show()

# %% [markdown]
# Modeling

# %%
reg=LinearRegression()
train_X=np.asanyarray(train[['ENGINESIZE']])
train_y=np.asanyarray(train[['CO2EMISSIONS']])
reg.fit(train_X,train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print ('Coefficients: ', reg.coef_)
print ('Intercept: ',reg.intercept_)
# Out:
# Coefficients:  [[39.55267435]]
# Intercept:  [123.97875441]

# %%
plt.scatter(train.ENGINESIZE, train.CO2EMISSIONS,  color='blue')
plt.plot(train_X, reg.coef_[0][0]*train_X + reg.intercept_[0], '-r')
plt.xlabel("Engine size")
plt.ylabel("Emission")
# Out:
# Text(0, 0.5, 'Emission')

# %%
import seaborn as sns
plt.scatter(train.ENGINESIZE, train.CO2EMISSIONS,  color='blue')
plt.plot(kind='reg')
plt.xlabel("Engine size")
plt.ylabel("Emission")
sns.regplot(x=train.ENGINESIZE,y=train.CO2EMISSIONS)
plt.show()
# Out:
# C:\Users\Shanto\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import r2_score

test_X = np.asanyarray(test[['ENGINESIZE']])
test_y = np.asanyarray(test[['CO2EMISSIONS']])
test_y_hat = reg.predict(test_X)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_hat - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_hat - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y_hat , test_y) )
# Out:
# Mean absolute error: 23.05
# Residual sum of squares (MSE): 919.38
# R2-score: 0.72

# %%
reg.predict(test_X)
# Out:
# array([[262.41311461],
#        [270.32364948],
#        [218.90517283],
#        [357.33953304],
#        [203.0841031 ],
#        [282.18945179],
#        [373.16060278],
#        [242.63677744],
#        [361.29480048],
#        [203.0841031 ],
#        [203.0841031 ],
#        [203.0841031 ],
#        [242.63677744],
#        [242.63677744],
#        [203.0841031 ],
#        [203.0841031 ],
#        [242.63677744],
#        [361.29480048],
#        [242.63677744],
#        [242.63677744],
#        [298.01052153],
#        [203.0841031 ],
#        [203.0841031 ],
#        [266.36838205],
#        [179.35249849],
#        [203.0841031 ],
#        [203.0841031 ],
#        [266.36838205],
#        [242.63677744],
#        [369.20533535],
#        [266.36838205],
#        [266.36838205],
#        [333.60792844],
#        [361.29480048],
#        [266.36838205],
#        [218.90517283],
#        [203.0841031 ],
#        [294.05525409],
#        [294.05525409],
#        [179.35249849],
# ...
